# %%
import pandas as pd
import pathlib
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go 
import plotly.figure_factory as ff
pio.renderers.default = "vscode"

# %%
caminho_bases = pathlib.Path(r"C:\Users\Kiwsley\Downloads\dataset")

meses = {'jan':1,'fev':2,'mar':3,'abr':4,'mai':5,'jun':6,'jul':7,'ago':8,'set':9,'out':10,'nov':11,'dez':12}


base_airbnb = pd.DataFrame()

for arquivo in caminho_bases.iterdir():
    nome_mes = arquivo.name[:3]
    mes=meses[nome_mes]

    ano = arquivo.name[-8:]
    ano= int(ano.replace('.csv',""))
    df = pd.read_csv(caminho_bases / arquivo.name)
    df['ano'] = ano
    df['mes'] = mes
    base_airbnb = pd.concat([df])

display(base_airbnb)
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\812231815.py:14: DtypeWarning:
#
# Columns (62,87) have mixed types. Specify dtype option on import or set low_memory=False.
#
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\812231815.py:14: DtypeWarning:
#
# Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\812231815.py:14: DtypeWarning:
#
# Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\812231815.py:14: DtypeWarning:
#
# Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\812231815.py:14: DtypeWarning:
#
# Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\812231815.py:14: DtypeWarning:
#
# ...

# %%
base_airbnb.head(1000).to_csv("primeiroregistros.csv")

# %%
#remover as colunas

##
# 1 id e informações não relevantes
# 2 colunas repetidas ou extremamente parecida com outra
# 3 colunas preenchidas com textos
# 
# 
# 
# ['host_response_time', 'host_response_rate', 'host_is_superhost', 'host_listings_count', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy', 'ano', 'mes']

# ##

# %%
colunas = ['host_response_time', 'host_response_rate', 'host_is_superhost', 'host_listings_count', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy', 'ano', 'mes']

base_airbnb = base_airbnb.loc[:,colunas]

display(base_airbnb)
# Out:
#        host_response_time host_response_rate host_is_superhost  \
# 0          within an hour               100%                 t
# 1      within a few hours               100%                 f
# 2          within an hour               100%                 t
# 3      within a few hours               100%                 t
# 4          within an hour               100%                 t
# ...                   ...                ...               ...
# 34324      within an hour                93%                 f
# 34325                 NaN                NaN                 f
# 34326  within a few hours                74%                 f
# 34327                 NaN                NaN                 f
# 34328  a few days or more                38%                 f
#
#        host_listings_count  latitude  longitude property_type  \
# 0                      2.0 -22.96592  -43.17896   Condominium
# 1                      3.0 -22.97712  -43.19045     Apartment
# ...

# %% [markdown]
# tratando valor nulos
#
# Visualizando os dados, notei que há muitos valores nulos, então, decidir excluir as colunas com mais de 11000 linhas nulas

# %%
for coluna in base_airbnb:
    if base_airbnb[coluna].isnull().sum()> 11000:
        base_airbnb=base_airbnb.drop(coluna, axis=1)
print(base_airbnb.isnull().sum())
# Out:
# host_is_superhost           14
# host_listings_count         14
# latitude                     0
# longitude                    0
# property_type                0
# room_type                    0
# accommodates                 0
# bathrooms                   57
# bedrooms                    29
# beds                        35
# bed_type                     0
# amenities                    0
# price                        0
# guests_included              0
# extra_people                 0
# minimum_nights               0
# maximum_nights               0
# number_of_reviews            0
# instant_bookable             0
# is_business_travel_ready     0
# cancellation_policy          0
# ano                          0
# mes                          0
# dtype: int64

# %%
base_airbnb=base_airbnb.dropna()

print(base_airbnb.shape)
print(base_airbnb.isnull().sum())
# Out:
# (34225, 23)
# host_is_superhost           0
# host_listings_count         0
# latitude                    0
# longitude                   0
# property_type               0
# room_type                   0
# accommodates                0
# bathrooms                   0
# bedrooms                    0
# beds                        0
# bed_type                    0
# amenities                   0
# price                       0
# guests_included             0
# extra_people                0
# minimum_nights              0
# maximum_nights              0
# number_of_reviews           0
# instant_bookable            0
# is_business_travel_ready    0
# cancellation_policy         0
# ano                         0
# mes                         0
# dtype: int64

# %%
#base_airbnb=base_airbnb.drop(columns='price', axis=1)
base_airbnb.head(1000).to_csv("primeiroregistros.csv")

# %% [markdown]
# verificando o tipo de dados

# %%
print(base_airbnb.dtypes)
print("-"*60)

print(base_airbnb.iloc[0])
# Out:
# host_is_superhost            object
# host_listings_count         float64
# latitude                    float64
# longitude                   float64
# property_type                object
# room_type                    object
# accommodates                  int64
# bathrooms                   float64
# bedrooms                    float64
# beds                        float64
# bed_type                     object
# amenities                    object
# price                        object
# guests_included               int64
# extra_people                 object
# minimum_nights                int64
# maximum_nights                int64
# number_of_reviews             int64
# instant_bookable             object
# is_business_travel_ready     object
# cancellation_policy          object
# ano                           int64
# mes                           int64
# dtype: object
# ------------------------------------------------------------
# ...

# %% [markdown]
# preço e extra people estão sendo reconhecido como objeto, porém é preciso deixar como float

# %%
#Price
base_airbnb['price'] = base_airbnb['price'].str.replace("$","")
base_airbnb['price'] = base_airbnb['price'].str.replace(",","")
base_airbnb['price'] = base_airbnb['price'].astype(float)

#extra people
base_airbnb['extra_people'] = base_airbnb['extra_people'].str.replace("$","")
base_airbnb['extra_people'] = base_airbnb['extra_people'].str.replace(",","")
base_airbnb['extra_people'] = base_airbnb['extra_people'].astype(float)

# %% [markdown]
# analise exploratoria e tratar outliers
#
# 1 verificar a correlação entre as feature

# %%
plt.figure(figsize=(15,5))
sns.heatmap(base_airbnb.corr(numeric_only=True),annot= True, cmap= 'Greens')
# Out:
# <Axes: >

# %% [markdown]
# definição de função para analise de outliers

# %%
def limites (coluna):
    q1 = coluna.quantile(0.25)
    q3 = coluna.quantile(0.75)
    amplitude = q3 -q1
    limite_inferior=q1-1.5 * amplitude
    limite_superior = q3+ 1.5 * amplitude
    return limite_inferior, limite_superior

def excluir_outliers(df,nome_coluna):
    qtde_linhas = df.shape[0]
    lim_inf , lim_sup = limites(df[nome_coluna])
    
    df = df.loc[(df[nome_coluna]>= lim_inf) & (df[nome_coluna]<= lim_sup),:]
    linha_removidas = qtde_linhas - df.shape[0] 
    return df, linha_removidas

# %%
print(limites(base_airbnb['price']))
# Out:
# (-526.5, 1277.5)

# %%
#realizando o diagrama de caixa para identificar outliers
def diagrama_caixa(coluna):
    fig, (ax1,ax2) = plt.subplots(1,2)
    fig.set_size_inches(15,5)
    sns.boxplot(x=coluna,ax=ax1)
    ax2.set_xlim(limites(coluna))
    sns.boxplot(x=coluna,ax=ax2)

def histograma(coluna):
    plt.figure(figsize=(15,5))
    sns.distplot(coluna,hist=True),

def grafico_barra(coluna):
    plt.figure(figsize=(15,5))
    ax = sns.barplot(x=coluna.value_counts().index,y=coluna.value_counts())
    ax.set_xlim(limites(coluna))

# %% [markdown]
# price

# %%
diagrama_caixa(base_airbnb['price'])
histograma(base_airbnb['price'])
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\388342814.py:11: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# como estamos construindo um modelo para imoveis comuns, acredito que podemos excluir os outrliers

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'price')

print(linhas_removidas)
# Out:
# 3319

# %%
histograma(base_airbnb['price'])
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\388342814.py:11: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Coluna extra people

# %%
diagrama_caixa(base_airbnb['extra_people'])
histograma(base_airbnb['extra_people'])
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\388342814.py:11: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'extra_people')

print(linhas_removidas)
# Out:
# 2243

# %% [markdown]
# ###host_listings_count

# %%
diagrama_caixa(base_airbnb['host_listings_count'])
grafico_barra(base_airbnb['host_listings_count'])

# %% [markdown]
# podemos excluir o outliers, porque para o objetivo do projeto hosts com mais de 6 imoveis no airbnb não são o publico do objetivo, provavelmente quem tem mais de 6 imoveis deve ser um imobiliaria

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'host_listings_count')

print(linhas_removidas)
# Out:
# 3901

# %% [markdown]
# coluna accommodates

# %%
diagrama_caixa(base_airbnb['accommodates'])
grafico_barra(base_airbnb['accommodates'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'accommodates')

print(linhas_removidas)
# Out:
# 494

# %% [markdown]
# coluna bathrooms

# %%
diagrama_caixa(base_airbnb['bathrooms'])
plt.figure(figsize=(15,5))

sns.barplot(x=base_airbnb['bathrooms'].value_counts().index,y= base_airbnb['bathrooms'].value_counts())
# Out:
# <Axes: xlabel='bathrooms', ylabel='count'>

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'bathrooms')

print(linhas_removidas)
# Out:
# 258

# %% [markdown]
# coluna bedrooms

# %%
diagrama_caixa(base_airbnb['bedrooms'])
grafico_barra(base_airbnb['bedrooms'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'bedrooms')

print(linhas_removidas)
# Out:
# 204

# %% [markdown]
# coluna beds

# %%
diagrama_caixa(base_airbnb['beds'])
grafico_barra(base_airbnb['beds'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'beds')

print(linhas_removidas)
# Out:
# 209

# %% [markdown]
# coluna guests_included

# %%
diagrama_caixa(base_airbnb['guests_included'])
grafico_barra(base_airbnb['guests_included'])
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\388342814.py:6: UserWarning:
#
# Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_7708\388342814.py:16: UserWarning:
#
# Attempting to set identical low and high xlims makes transformation singular; automatically expanding.

# %% [markdown]
# remover a coluna da analise, pois está basicamente como uma constante 1, como se fosse um valor padrão

# %%
base_airbnb = base_airbnb.drop("guests_included",axis =1)
base_airbnb.shape
# Out:
# (23597, 22)

# %% [markdown]
# Coluna minimum_nights

# %%
diagrama_caixa(base_airbnb['minimum_nights'])
grafico_barra(base_airbnb['minimum_nights'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'minimum_nights')

print(linhas_removidas)
# Out:
# 1578

# %% [markdown]
# Coluna maximum_nights

# %%
diagrama_caixa(base_airbnb['maximum_nights'])
grafico_barra(base_airbnb['maximum_nights'])

# %%
#removendo a coluna 

base_airbnb = base_airbnb.drop("maximum_nights",axis =1)
base_airbnb.shape
# Out:
# (22019, 21)

# %% [markdown]
# Coluna number_of_reviews

# %%
diagrama_caixa(base_airbnb['number_of_reviews'])
grafico_barra(base_airbnb['number_of_reviews'])

# %%
#removendo a coluna 

base_airbnb = base_airbnb.drop("number_of_reviews",axis =1)
base_airbnb.shape
# Out:
# (22019, 20)

# %% [markdown]
# Tratamento de colunas de valores de texto

# %% [markdown]
# coluna property_type

# %%
print(base_airbnb['property_type'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='property_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# property_type
# Apartment                 17154
# House                      1965
# Condominium                1227
# Loft                        478
# Serviced apartment          470
# Guest suite                 152
# Bed and breakfast            96
# Guesthouse                   84
# Other                        62
# Villa                        58
# Hostel                       52
# Townhouse                    36
# Aparthotel                   28
# Tiny house                   23
# Earth house                  22
# Chalet                       20
# Boutique hotel               15
# Cottage                      13
# Bungalow                     10
# Hotel                         9
# Nature lodge                  7
# Cabin                         6
# Casa particular (Cuba)        6
# Treehouse                     5
# Castle                        4
# Boat                          3
# Island                        2
# Campsite                      2
# ...

# %%
tabela_tipo_casa = base_airbnb['property_type'].value_counts()
colunas_agrupar = []
for tipo in tabela_tipo_casa.index:
    if tabela_tipo_casa[tipo]<200:
        colunas_agrupar.append(tipo)
print(colunas_agrupar)

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['property_type']==tipo,'property_type'] = 'Outros'

print(base_airbnb['property_type'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='property_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# ['Guest suite', 'Bed and breakfast', 'Guesthouse', 'Other', 'Villa', 'Hostel', 'Townhouse', 'Aparthotel', 'Tiny house', 'Earth house', 'Chalet', 'Boutique hotel', 'Cottage', 'Bungalow', 'Hotel', 'Nature lodge', 'Cabin', 'Casa particular (Cuba)', 'Treehouse', 'Castle', 'Boat', 'Island', 'Campsite', 'Hut', 'Dorm', 'Igloo', 'Camper/RV', 'Tipi', 'Dome house', 'Yurt', 'Barn']
# property_type
# Apartment             17154
# House                  1965
# Condominium            1227
# Outros                  725
# Loft                    478
# Serviced apartment      470
# Name: count, dtype: int64

# %% [markdown]
# Coluna
#
# room_type

# %%
print(base_airbnb['room_type'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='room_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# room_type
# Entire home/apt    13972
# Private room        7464
# Shared room          444
# Hotel room           139
# Name: count, dtype: int64

# %% [markdown]
# Coluna
#
# bed_type

# %%
print(base_airbnb['bed_type'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='bed_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)


#agrupando categoria de cancellation

tabela_bed = base_airbnb['bed_type'].value_counts()

colunas_agrupar = []
for tipo in tabela_bed.index:
    if tabela_bed[tipo]<500:
        colunas_agrupar.append(tipo)
print(colunas_agrupar)

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['bed_type']==tipo,'bed_type'] = 'other'

print(base_airbnb['bed_type'].value_counts())


plt.figure(figsize=(10,3))
grafico = sns.countplot(x='bed_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# bed_type
# Real Bed         21613
# Pull-out Sofa      293
# Futon               55
# Airbed              39
# Couch               19
# Name: count, dtype: int64
# ['Pull-out Sofa', 'Futon', 'Airbed', 'Couch']
# bed_type
# Real Bed    21613
# other         406
# Name: count, dtype: int64

# %% [markdown]
# cancellation_policy

# %%
print(base_airbnb['cancellation_policy'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='cancellation_policy', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)

#agrupando categoria de cancellation

tabela_cancellation = base_airbnb['cancellation_policy'].value_counts()

colunas_agrupar = []
for tipo in tabela_cancellation.index:
    if tabela_cancellation[tipo]<500:
        colunas_agrupar.append(tipo)
print(colunas_agrupar)

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['cancellation_policy']==tipo,'cancellation_policy'] = 'other'

print(base_airbnb['cancellation_policy'].value_counts())


plt.figure(figsize=(10,3))
grafico = sns.countplot(x='cancellation_policy', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# cancellation_policy
# flexible                       9905
# strict_14_with_grace_period    7884
# moderate                       4223
# super_strict_60                   6
# strict                            1
# Name: count, dtype: int64
# ['super_strict_60', 'strict']
# cancellation_policy
# flexible                       9905
# strict_14_with_grace_period    7884
# moderate                       4223
# other                             7
# Name: count, dtype: int64

# %% [markdown]
# como temos uma diversidade de amenities, as mesma amenites podem ser escritas de forma diferente. portanto, voou avaliar o numero de amenities

# %%
print(base_airbnb['amenities'].iloc[0].split(','))

base_airbnb ['n_amenities'] = base_airbnb['amenities'].str.split(',').apply(len)
# Out:
# ['{TV', '"Cable TV"', 'Internet', 'Wifi', '"Air conditioning"', 'Kitchen', '"Paid parking off premises"', '"Smoking allowed"', 'Doorman', 'Elevator', '"Hot tub"', '"Family/kid friendly"', '"Suitable for events"', 'Essentials', '"24-hour check-in"', 'Hangers', '"Hair dryer"', 'Iron', '"Laptop friendly workspace"', '"Self check-in"', '"Building staff"', '"Private entrance"', '"Hot water"', '"Bed linens"', 'Microwave', '"Coffee maker"', 'Refrigerator', '"Dishes and silverware"', '"Cooking basics"', 'Oven', 'Stove', '"Patio or balcony"', '"Luggage dropoff allowed"}']

# %%
base_airbnb = base_airbnb.drop("amenities",axis =1)
base_airbnb.shape
# Out:
# (22019, 20)

# %%
diagrama_caixa(base_airbnb['n_amenities'])
grafico_barra(base_airbnb['n_amenities'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'n_amenities')

print(linhas_removidas)
base_airbnb.shape
# Out:
# 709
# (21310, 20)

# %% [markdown]
# Visualização de mapa das propriedades

# %%
amostra = base_airbnb.sample(n=5000)
#pio.renderers.default = "notebook_connected"

centro_mapa ={'lat':amostra.latitude.mean(), 'lon':amostra.longitude.mean()}

mapa = px.density_mapbox(amostra, lat ='latitude', lon='longitude', z='price',radius=5,
                        center=centro_mapa,zoom=12,mapbox_style='open-street-map')

# %%
mapa.show()

# %%
coluna_tf = ['host_is_superhost','instant_bookable','is_business_travel_ready']
#print (base_airbnb.columns)
base_airbnb_cod = base_airbnb.copy()

for coluna in coluna_tf:
    base_airbnb_cod.loc[base_airbnb_cod[coluna]=='t',coluna]=1
    base_airbnb_cod.loc[base_airbnb_cod[coluna]=='f',coluna]=0

base_airbnb_cod.iloc[0]
# Out:
# host_is_superhost                                     1
# host_listings_count                                 2.0
# latitude                                      -22.96592
# longitude                                     -43.17896
# property_type                               Condominium
# room_type                               Entire home/apt
# accommodates                                          5
# bathrooms                                           1.0
# bedrooms                                            2.0
# beds                                                2.0
# bed_type                                       Real Bed
# price                                             329.0
# extra_people                                       62.0
# minimum_nights                                        4
# instant_bookable                                      1
# is_business_travel_ready                              0
# cancellation_policy         strict_14_with_grace_period
# ...

# %%
colunas_categorias = ['property_type','room_type','bed_type','cancellation_policy']
