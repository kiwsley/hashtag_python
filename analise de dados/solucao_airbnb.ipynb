# %%
import pandas as pd
import pathlib
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.model_selection import train_test_split

# %%
caminho_bases = pathlib.Path(r"C:\Users\Kiwsley\Downloads\Nova pasta (7)")
#Arquivo grande não subir para o repositorio git
base_airbnb = pd.read_csv(r"C:\Users\Kiwsley\Downloads\Nova pasta (7)\total_data.csv")    

display(base_airbnb)
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_14308\4109140194.py:3: DtypeWarning:
#
# Columns (1,17,19,20,28,33,34,54,62,63,66,68,69,88) have mixed types. Specify dtype option on import or set low_memory=False.
#         Unnamed: 0        id                            listing_url  \
# 0              0.0     17878     https://www.airbnb.com/rooms/17878
# 1              1.0     24480     https://www.airbnb.com/rooms/24480
# 2              2.0     25026     https://www.airbnb.com/rooms/25026
# 3              3.0     31560     https://www.airbnb.com/rooms/31560
# 4              4.0     35636     https://www.airbnb.com/rooms/35636
# ...            ...       ...                                    ...
# 784117     35788.0  43514675  https://www.airbnb.com/rooms/43514675
# 784118     35789.0  43515526  https://www.airbnb.com/rooms/43515526
# 784119     35790.0  43517044  https://www.airbnb.com/rooms/43517044
# 784120     35791.0  43522964  https://www.airbnb.com/rooms/43522964
# 784121     35792.0  43524785  https://www.airbnb.com/rooms/43524785
#
#            scrape_id last_scraped                                       name  \
# 0       2.018082e+13   2018-08-16          Very Nice 2Br - Copacabana - WiFi
# 1       2.018082e+13   2018-08-16           Nice and cozy near Ipanema Beach
# 2       2.018082e+13   2018-08-16  Beautiful Modern Decorated Studio in Copa
# 3       2.018082e+13   2018-08-16           NICE & COZY 1BDR - IPANEMA BEACH
# 4       2.018082e+13   2018-08-16           Cosy flat close to Ipanema beach
# ...              ...          ...                                        ...
# 784117  2.020052e+13   2020-05-25                           Quarto no Leblon
# 784118  2.020052e+13   2020-05-25      Lindo Apartamento, 2 quadras da praia
# 784119  2.020052e+13   2020-05-26    Conforto e concentração pra sua estadia
# 784120  2.020052e+13   2020-05-26                                Botafogo ll
# 784121  2.020052e+13   2020-05-25       QUARTÃO EM COPACABANA, DIAS ou MESES
#
#                                                   summary  \
# 0       Please note that special rates apply for New Y...
# 1       My studio is located in the best  of Ipanema. ...
# 2       Our apartment is a little gem, everyone loves ...
# 3       This nice and clean 1 bedroom apartment is loc...
# 4       This cosy apartment  is just a few steps away ...
# ...                                                   ...
# 784117  Meu apartamento é simples e muito aconchegante...
# 784118                                                NaN
# 784119                                                NaN
# 784120  Excelente apartamento 2 quartos e dois banheir...
# 784121  QUARTO AMPLO E AREJADO, CORAÇÃO DE COPACABANA ...
#
#                                                     space  \
# 0       - large balcony which looks out on pedestrian ...
# 1       The studio is located at Vinicius de Moraes St...
# 2       This newly renovated studio (last renovations ...
# 3       This nice and clean 1 bedroom apartment is loc...
# 4       The location is extremely convenient, safe and...
# ...                                                   ...
# 784117                                                NaN
# 784118                                                NaN
# 784119                                                NaN
# 784120                                                NaN
# 784121  Está Localizado na Rua Principal de Copacabana...
#
#                                               description experiences_offered  \
# 0       Please note that special rates apply for New Y...                none
# 1       My studio is located in the best  of Ipanema. ...                none
# 2       Our apartment is a little gem, everyone loves ...                none
# 3       This nice and clean 1 bedroom apartment is loc...                none
# 4       This cosy apartment  is just a few steps away ...                none
# ...                                                   ...                 ...
# 784117  Meu apartamento é simples e muito aconchegante...                none
# 784118                                                NaN                none
# 784119                                                NaN                none
# 784120  Excelente apartamento 2 quartos e dois banheir...                none
# 784121  QUARTO AMPLO E AREJADO, CORAÇÃO DE COPACABANA ...                none
#
#         ... minimum_minimum_nights maximum_minimum_nights  \
# 0       ...                    NaN                    NaN
# 1       ...                    NaN                    NaN
# 2       ...                    NaN                    NaN
# 3       ...                    NaN                    NaN
# 4       ...                    NaN                    NaN
# ...     ...                    ...                    ...
# 784117  ...                    2.0                    2.0
# 784118  ...                    1.0                    1.0
# 784119  ...                    2.0                    2.0
# 784120  ...                    4.0                    4.0
# 784121  ...                    1.0                    1.0
#
#        minimum_maximum_nights maximum_maximum_nights minimum_nights_avg_ntm  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 784117                 1125.0                 1125.0                    2.0
# 784118                 1125.0                 1125.0                    1.0
# 784119                  365.0                  365.0                    2.0
# 784120                 1125.0                 1125.0                    4.0
# 784121                 1125.0                 1125.0                    1.0
#
#        maximum_nights_avg_ntm  number_of_reviews_ltm  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# ...                       ...                    ...
# 784117                 1125.0                    0.0
# 784118                 1125.0                    0.0
# 784119                  365.0                    0.0
# 784120                 1125.0                    0.0
# 784121                 1125.0                    0.0
#
#        calculated_host_listings_count_entire_homes  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 784117                                         0.0
# 784118                                         2.0
# 784119                                         0.0
# 784120                                        49.0
# 784121                                         2.0
#
#        calculated_host_listings_count_private_rooms  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 784117                                          1.0
# 784118                                          0.0
# 784119                                          1.0
# 784120                                          0.0
# 784121                                          1.0
#
#        calculated_host_listings_count_shared_rooms
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 784117                                         0.0
# 784118                                         0.0
# 784119                                         0.0
# 784120                                         0.0
# 784121                                         0.0
#
# [784122 rows x 108 columns]

# %%
base_airbnb.head(1000).to_csv("primeiroregistros.csv")

# %%
colunas = ['host_response_time', 'host_response_rate', 'host_is_superhost', 'host_listings_count', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy']

base_airbnb = base_airbnb.loc[:,colunas]

display(base_airbnb)
# Out:
#         host_response_time host_response_rate host_is_superhost  \
# 0           within an hour               100%                 f
# 1                      NaN                NaN                 f
# 2       within a few hours               100%                 f
# 3           within an hour               100%                 t
# 4           within an hour               100%                 f
# ...                    ...                ...               ...
# 784117                 NaN                NaN                 f
# 784118      within an hour                80%                 f
# 784119                 NaN                NaN                 f
# 784120      within an hour               100%                 t
# 784121  within a few hours                90%                 f
#
#        host_listings_count   latitude  longitude property_type  \
# 0                      2.0 -22.965919 -43.178962   Condominium
# 1                      1.0 -22.985698 -43.201935     Apartment
# 2                      3.0 -22.977117 -43.190454     Apartment
# 3                      1.0 -22.983024 -43.214270     Apartment
# 4                      1.0 -22.988165 -43.193588     Apartment
# ...                    ...        ...        ...           ...
# 784117                 0.0 -22.982870 -43.220140     Apartment
# 784118                 2.0 -22.977930 -43.189500     Apartment
# 784119                 1.0 -22.925610 -43.361750   Condominium
# 784120                54.0 -22.952230 -43.183550     Apartment
# 784121                 4.0 -22.970050 -43.187690     Apartment
#
#               room_type accommodates  bathrooms  ...  review_scores_rating  \
# 0       Entire home/apt            5        1.0  ...                  93.0
# 1       Entire home/apt            2        1.0  ...                  95.0
# 2       Entire home/apt            3        1.0  ...                  94.0
# 3       Entire home/apt            3        1.0  ...                  96.0
# 4       Entire home/apt            3        1.5  ...                  94.0
# ...                 ...          ...        ...  ...                   ...
# 784117     Private room            1        1.0  ...                   NaN
# 784118  Entire home/apt            6        2.5  ...                   NaN
# 784119     Private room            2        1.0  ...                   NaN
# 784120  Entire home/apt            3        2.0  ...                   NaN
# 784121     Private room            4        2.0  ...                   NaN
#
#         review_scores_accuracy review_scores_cleanliness  \
# 0                         10.0                       9.0
# 1                         10.0                      10.0
# 2                          9.0                      10.0
# 3                         10.0                      10.0
# 4                         10.0                       9.0
# ...                        ...                       ...
# 784117                     NaN                       NaN
# 784118                     NaN                       NaN
# 784119                     NaN                       NaN
# 784120                     NaN                       NaN
# 784121                     NaN                       NaN
#
#        review_scores_checkin review_scores_communication  \
# 0                       10.0                        10.0
# 1                       10.0                        10.0
# 2                       10.0                        10.0
# 3                       10.0                        10.0
# 4                       10.0                        10.0
# ...                      ...                         ...
# 784117                   NaN                         NaN
# 784118                   NaN                         NaN
# 784119                   NaN                         NaN
# 784120                   NaN                         NaN
# 784121                   NaN                         NaN
#
#        review_scores_location review_scores_value instant_bookable  \
# 0                         9.0                 9.0                t
# 1                        10.0                 9.0                f
# 2                        10.0                 9.0                f
# 3                        10.0                 9.0                t
# 4                        10.0                 9.0                f
# ...                       ...                 ...              ...
# 784117                    NaN                 NaN                t
# 784118                    NaN                 NaN                t
# 784119                    NaN                 NaN                f
# 784120                    NaN                 NaN                t
# 784121                    NaN                 NaN                f
#
#        is_business_travel_ready          cancellation_policy
# 0                             f  strict_14_with_grace_period
# 1                             f  strict_14_with_grace_period
# 2                             f  strict_14_with_grace_period
# 3                             f  strict_14_with_grace_period
# 4                             f  strict_14_with_grace_period
# ...                         ...                          ...
# 784117                        f                     flexible
# 784118                        f                     flexible
# 784119                        f                     flexible
# 784120                        f                     flexible
# 784121                        f                     flexible
#
# [784122 rows x 32 columns]

# %% [markdown]
# tratando valor nulos
#
# Visualizando os dados, notei que há muitos valores nulos, então, decidir excluir as colunas com mais de 11000 linhas nulas

# %%
for coluna in base_airbnb:
    if base_airbnb[coluna].isnull().sum()> 11000:
        base_airbnb=base_airbnb.drop(coluna, axis=1)
print(base_airbnb.isnull().sum())
# Out:
# host_is_superhost            386
# host_listings_count          386
# latitude                       1
# longitude                      1
# property_type                  1
# room_type                      1
# accommodates                   1
# bathrooms                   1494
# bedrooms                     776
# beds                        2335
# bed_type                       1
# amenities                      1
# price                          1
# guests_included                1
# extra_people                   1
# minimum_nights                 1
# maximum_nights                 1
# number_of_reviews              1
# instant_bookable               2
# is_business_travel_ready       2
# cancellation_policy            2
# dtype: int64

# %%
base_airbnb=base_airbnb.dropna()

print(base_airbnb.shape)
print(base_airbnb.isnull().sum())
# Out:
# (780035, 21)
# host_is_superhost           0
# host_listings_count         0
# latitude                    0
# longitude                   0
# property_type               0
# room_type                   0
# accommodates                0
# bathrooms                   0
# bedrooms                    0
# beds                        0
# bed_type                    0
# amenities                   0
# price                       0
# guests_included             0
# extra_people                0
# minimum_nights              0
# maximum_nights              0
# number_of_reviews           0
# instant_bookable            0
# is_business_travel_ready    0
# cancellation_policy         0
# dtype: int64

# %%
#base_airbnb=base_airbnb.drop(columns='price', axis=1)
base_airbnb.head(1000).to_csv("primeiroregistros.csv")

# %% [markdown]
# verificando o tipo de dados

# %%
print(base_airbnb.dtypes)
print("-"*60)

print(base_airbnb.iloc[0])
# Out:
# host_is_superhost            object
# host_listings_count          object
# latitude                    float64
# longitude                   float64
# property_type                object
# room_type                    object
# accommodates                 object
# bathrooms                   float64
# bedrooms                    float64
# beds                        float64
# bed_type                     object
# amenities                    object
# price                        object
# guests_included              object
# extra_people                 object
# minimum_nights               object
# maximum_nights               object
# number_of_reviews           float64
# instant_bookable             object
# is_business_travel_ready     object
# cancellation_policy          object
# dtype: object
# ------------------------------------------------------------
# host_is_superhost                                                           f
# host_listings_count                                                       2.0
# latitude                                                           -22.965919
# longitude                                                          -43.178962
# property_type                                                     Condominium
# room_type                                                     Entire home/apt
# accommodates                                                                5
# bathrooms                                                                 1.0
# bedrooms                                                                  2.0
# beds                                                                      2.0
# bed_type                                                             Real Bed
# amenities                   {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# price                                                                 $307.00
# guests_included                                                             2
# extra_people                                                           $58.00
# minimum_nights                                                              4
# maximum_nights                                                             90
# number_of_reviews                                                       213.0
# instant_bookable                                                            t
# is_business_travel_ready                                                    f
# cancellation_policy                               strict_14_with_grace_period
# Name: 0, dtype: object

# %% [markdown]
# preço e extra people estão sendo reconhecido como objeto, porém é preciso deixar como float

# %%
#Price
base_airbnb['price'] = base_airbnb['price'].str.replace("$","")
base_airbnb['price'] = base_airbnb['price'].str.replace(",","")
base_airbnb['price'] = base_airbnb['price'].astype(np.float32, copy=False)

#extra people
base_airbnb['extra_people'] = base_airbnb['extra_people'].str.replace("$","")
base_airbnb['extra_people'] = base_airbnb['extra_people'].str.replace(",","")
base_airbnb['extra_people'] = base_airbnb['extra_people'].astype(np.float32, copy=False)

# %% [markdown]
# analise exploratoria e tratar outliers
#
# 1 verificar a correlação entre as feature

# %%
plt.figure(figsize=(15,5))
sns.heatmap(base_airbnb.corr(numeric_only=True),annot= True, cmap= 'Greens')
# Out:
# <Axes: >

# %% [markdown]
# definição de função para analise de outliers

# %%
def limites(coluna):
    q1 = coluna.quantile(0.25)
    q3 = coluna.quantile(0.75)
    amplitude = q3 - q1
    return q1 - 1.5 * amplitude, q3 + 1.5 * amplitude
def excluir_outliers(df, nome_coluna):
    qtde_linhas = df.shape[0]
    lim_inf, lim_sup = limites(df[nome_coluna])
    df = df.loc[(df[nome_coluna] >= lim_inf) & (df[nome_coluna] <= lim_sup), :]
    linhas_removidas = qtde_linhas - df.shape[0]
    return df,  linhas_removidas

# %%
print(limites(base_airbnb['price']))
# Out:
# (-521.5, 1274.5)

# %%
#realizando o diagrama de caixa para identificar outliers
def diagrama_caixa(coluna):
    fig, (ax1,ax2) = plt.subplots(1,2)
    fig.set_size_inches(15,5)
    sns.boxplot(x=coluna,ax=ax1)
    ax2.set_xlim(limites(coluna))
    sns.boxplot(x=coluna,ax=ax2)

def histograma(coluna):
    plt.figure(figsize=(15,5))
    sns.distplot(coluna,hist=True),

def grafico_barra(coluna):
    plt.figure(figsize=(15,5))
    ax = sns.barplot(x=coluna.value_counts().index,y=coluna.value_counts())
    ax.set_xlim(limites(coluna))

# %% [markdown]
# price

# %%
diagrama_caixa(base_airbnb['price'])
histograma(base_airbnb['price'])
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_14308\388342814.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(coluna,hist=True),

# %% [markdown]
# como estamos construindo um modelo para imoveis comuns, acredito que podemos excluir os outrliers

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'price')

print(linhas_removidas)
# Out:
# 76756

# %%
histograma(base_airbnb['price'])
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_14308\388342814.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(coluna,hist=True),

# %% [markdown]
# Coluna extra people

# %%
diagrama_caixa(base_airbnb['extra_people'])
histograma(base_airbnb['extra_people'])
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_14308\388342814.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(coluna,hist=True),

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'extra_people')

print(linhas_removidas)
# Out:
# 51635

# %% [markdown]
# ###host_listings_count

# %%
base_airbnb['host_listings_count'] = base_airbnb['host_listings_count'].astype(np.float32)
diagrama_caixa(base_airbnb['host_listings_count'])
grafico_barra(base_airbnb['host_listings_count'])

# %% [markdown]
# podemos excluir o outliers, porque para o objetivo do projeto hosts com mais de 6 imoveis no airbnb não são o publico do objetivo, provavelmente quem tem mais de 6 imoveis deve ser um imobiliaria

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'host_listings_count')

print(linhas_removidas)
# Out:
# 84752

# %% [markdown]
# coluna accommodates

# %%
base_airbnb['accommodates'] = base_airbnb['accommodates'].astype(np.float32)

diagrama_caixa(base_airbnb['accommodates'])
grafico_barra(base_airbnb['accommodates'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'accommodates')

print(linhas_removidas)
# Out:
# 11382

# %% [markdown]
# coluna bathrooms

# %%
diagrama_caixa(base_airbnb['bathrooms'])
plt.figure(figsize=(15,5))

sns.barplot(x=base_airbnb['bathrooms'].value_counts().index,y= base_airbnb['bathrooms'].value_counts())
# Out:
# <Axes: xlabel='bathrooms', ylabel='count'>

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'bathrooms')

print(linhas_removidas)
# Out:
# 5925

# %% [markdown]
# coluna bedrooms

# %%
diagrama_caixa(base_airbnb['bedrooms'])
grafico_barra(base_airbnb['bedrooms'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'bedrooms')

print(linhas_removidas)
# Out:
# 4723

# %% [markdown]
# coluna beds

# %%
diagrama_caixa(base_airbnb['beds'])
grafico_barra(base_airbnb['beds'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'beds')

print(linhas_removidas)
# Out:
# 4887

# %% [markdown]
# coluna guests_included

# %%
base_airbnb['guests_included'] = base_airbnb['guests_included'].astype(np.float32)

diagrama_caixa(base_airbnb['guests_included'])
grafico_barra(base_airbnb['guests_included'])
# Out:
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_14308\388342814.py:6: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax2.set_xlim(limites(coluna))
# C:\Users\Kiwsley\AppData\Local\Temp\ipykernel_14308\388342814.py:16: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(limites(coluna))

# %% [markdown]
# remover a coluna da analise, pois está basicamente como uma constante 1, como se fosse um valor padrão

# %%
base_airbnb = base_airbnb.drop("guests_included",axis =1)
base_airbnb.shape
# Out:
# (539975, 20)

# %% [markdown]
# Coluna minimum_nights

# %%
base_airbnb['minimum_nights'] = base_airbnb['minimum_nights'].astype(np.float32)

diagrama_caixa(base_airbnb['minimum_nights'])
grafico_barra(base_airbnb['minimum_nights'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'minimum_nights')

print(linhas_removidas)
# Out:
# 35893

# %% [markdown]
# Coluna maximum_nights

# %%
#removendo a coluna 

base_airbnb = base_airbnb.drop("maximum_nights",axis =1)
base_airbnb.shape
# Out:
# (504082, 19)

# %% [markdown]
# Coluna number_of_reviews

# %%
diagrama_caixa(base_airbnb['number_of_reviews'])
grafico_barra(base_airbnb['number_of_reviews'])

# %%
#removendo a coluna 

base_airbnb = base_airbnb.drop("number_of_reviews",axis =1)
base_airbnb.shape
# Out:
# (504082, 18)

# %% [markdown]
# Tratamento de colunas de valores de texto

# %% [markdown]
# coluna property_type

# %%
print(base_airbnb['property_type'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='property_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# property_type
# Apartment                 394471
# House                      44486
# Condominium                24978
# Serviced apartment         11322
# Loft                       10967
# Guest suite                 3288
# Bed and breakfast           2833
# Hostel                      2210
# Guesthouse                  1905
# Other                       1556
# Villa                       1131
# Townhouse                    870
# Aparthotel                   608
# Tiny house                   446
# Earth house                  435
# Chalet                       422
# Boutique hotel               407
# Hotel                        354
# Casa particular (Cuba)       269
# Cottage                      214
# Bungalow                     195
# Cabin                        128
# Nature lodge                 112
# Treehouse                     67
# Castle                        63
# Island                        50
# Boat                          46
# Hut                           34
# Campsite                      34
# Dorm                          29
# Resort                        25
# Camper/RV                     24
# Yurt                          22
# Barn                          15
# Tipi                          14
# Tent                          12
# Farm stay                     11
# Pension (South Korea)          9
# Dome house                     8
# Igloo                          6
# Houseboat                      3
# Casa particular                2
# Plane                          1
# Name: count, dtype: int64

# %%
tabela_tipo_casa = base_airbnb['property_type'].value_counts()
colunas_agrupar = []
for tipo in tabela_tipo_casa.index:
    if tabela_tipo_casa[tipo]<4000:
        colunas_agrupar.append(tipo)
print(colunas_agrupar)

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['property_type']==tipo,'property_type'] = 'Outros'

print(base_airbnb['property_type'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='property_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# ['Guest suite', 'Bed and breakfast', 'Hostel', 'Guesthouse', 'Other', 'Villa', 'Townhouse', 'Aparthotel', 'Tiny house', 'Earth house', 'Chalet', 'Boutique hotel', 'Hotel', 'Casa particular (Cuba)', 'Cottage', 'Bungalow', 'Cabin', 'Nature lodge', 'Treehouse', 'Castle', 'Island', 'Boat', 'Hut', 'Campsite', 'Dorm', 'Resort', 'Camper/RV', 'Yurt', 'Barn', 'Tipi', 'Tent', 'Farm stay', 'Pension (South Korea)', 'Dome house', 'Igloo', 'Houseboat', 'Casa particular', 'Plane']
# property_type
# Apartment             394471
# House                  44486
# Condominium            24978
# Outros                 17858
# Serviced apartment     11322
# Loft                   10967
# Name: count, dtype: int64

# %% [markdown]
# Coluna
#
# room_type

# %%
print(base_airbnb['room_type'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='room_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# room_type
# Entire home/apt    323176
# Private room       169883
# Shared room         10056
# Hotel room            967
# Name: count, dtype: int64

# %% [markdown]
# Coluna
#
# bed_type

# %%
print(base_airbnb['bed_type'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='bed_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)


#agrupando categoria de cancellation

tabela_bed = base_airbnb['bed_type'].value_counts()

colunas_agrupar = []
for tipo in tabela_bed.index:
    if tabela_bed[tipo]<5000:
        colunas_agrupar.append(tipo)
print(colunas_agrupar)

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['bed_type']==tipo,'bed_type'] = 'other'

print(base_airbnb['bed_type'].value_counts())


plt.figure(figsize=(10,3))
grafico = sns.countplot(x='bed_type', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# bed_type
# Real Bed         494555
# Pull-out Sofa      6778
# Futon              1364
# Airbed              968
# Couch               417
# Name: count, dtype: int64
# ['Futon', 'Airbed', 'Couch']
# bed_type
# Real Bed         494555
# Pull-out Sofa      6778
# other              2749
# Name: count, dtype: int64

# %% [markdown]
# cancellation_policy

# %%
print(base_airbnb['cancellation_policy'].value_counts())

plt.figure(figsize=(10,3))
grafico = sns.countplot(x='cancellation_policy', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)

#agrupando categoria de cancellation

tabela_cancellation = base_airbnb['cancellation_policy'].value_counts()

colunas_agrupar = []
for tipo in tabela_cancellation.index:
    if tabela_cancellation[tipo]<5000:
        colunas_agrupar.append(tipo)
print(colunas_agrupar)

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['cancellation_policy']==tipo,'cancellation_policy'] = 'other'

print(base_airbnb['cancellation_policy'].value_counts())


plt.figure(figsize=(10,3))
grafico = sns.countplot(x='cancellation_policy', data=base_airbnb)
grafico.tick_params(axis='x',rotation = 90)
# Out:
# cancellation_policy
# flexible                       223321
# strict_14_with_grace_period    181858
# moderate                        98714
# super_strict_60                   132
# super_strict_30                    29
# strict                             28
# Name: count, dtype: int64
# ['super_strict_60', 'super_strict_30', 'strict']
# cancellation_policy
# flexible                       223321
# strict_14_with_grace_period    181858
# moderate                        98714
# other                             189
# Name: count, dtype: int64

# %% [markdown]
# como temos uma diversidade de amenities, as mesma amenites podem ser escritas de forma diferente. portanto, voou avaliar o numero de amenities

# %%
print(base_airbnb['amenities'].iloc[0].split(','))

base_airbnb ['n_amenities'] = base_airbnb['amenities'].str.split(',').apply(len)
# Out:
# ['{TV', '"Cable TV"', 'Internet', 'Wifi', '"Air conditioning"', 'Kitchen', '"Paid parking off premises"', '"Smoking allowed"', 'Doorman', 'Elevator', '"Hot tub"', '"Family/kid friendly"', '"Suitable for events"', 'Essentials', '"24-hour check-in"', 'Hangers', '"Hair dryer"', 'Iron', '"Laptop friendly workspace"', '"Self check-in"', '"Building staff"', '"Private entrance"', '"Hot water"', '"Bed linens"', '"Luggage dropoff allowed"}']

# %%
base_airbnb = base_airbnb.drop("amenities",axis =1)
base_airbnb.shape
# Out:
# (504082, 18)

# %%
diagrama_caixa(base_airbnb['n_amenities'])
grafico_barra(base_airbnb['n_amenities'])

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'n_amenities')

print(linhas_removidas)
base_airbnb.shape
# Out:
# 15025
# (489057, 18)

# %% [markdown]
# Visualização de mapa das propriedades

# %%
amostra = base_airbnb.sample(n=5000)
#pio.renderers.default = "notebook_connected"

centro_mapa ={'lat':amostra.latitude.mean(), 'lon':amostra.longitude.mean()}

mapa = px.density_mapbox(amostra, lat ='latitude', lon='longitude', z='price',radius=5,
                        center=centro_mapa,zoom=12,mapbox_style='open-street-map')

# %%
mapa.show()

# %%
colunas_tf = ['host_is_superhost', 'instant_bookable', 'is_business_travel_ready']
base_airbnb_cod = base_airbnb.copy()
for coluna in colunas_tf:
    base_airbnb_cod.loc[base_airbnb_cod[coluna]=='t', coluna] = 1
    base_airbnb_cod.loc[base_airbnb_cod[coluna]=='f', coluna] = 0

# %%
colunas_categorias = ['property_type', 'room_type', 'bed_type', 'cancellation_policy']
base_airbnb_cod = pd.get_dummies(data=base_airbnb_cod, columns=colunas_categorias)
display(base_airbnb_cod.head())
# Out:
#   host_is_superhost  host_listings_count   latitude  longitude  accommodates  \
# 0                 0                  2.0 -22.965919 -43.178962           5.0
# 2                 0                  3.0 -22.977117 -43.190454           3.0
# 3                 1                  1.0 -22.983024 -43.214270           3.0
# 4                 0                  1.0 -22.988165 -43.193588           3.0
# 5                 1                  1.0 -22.981269 -43.190457           2.0
#
#    bathrooms  bedrooms  beds  price  extra_people  ...  room_type_Hotel room  \
# 0        1.0       2.0   2.0  307.0          58.0  ...                 False
# 2        1.0       1.0   2.0  159.0          45.0  ...                 False
# 3        1.0       1.0   2.0  253.0          39.0  ...                 False
# 4        1.5       1.0   2.0  350.0          58.0  ...                 False
# 5        1.0       1.0   2.0  221.0          80.0  ...                 False
#
#   room_type_Private room room_type_Shared room  bed_type_Pull-out Sofa  \
# 0                  False                 False                   False
# 2                  False                 False                   False
# 3                  False                 False                   False
# 4                  False                 False                   False
# 5                  False                 False                   False
#
#    bed_type_Real Bed  bed_type_other  cancellation_policy_flexible  \
# 0               True           False                         False
# 2               True           False                         False
# 3               True           False                         False
# 4               True           False                         False
# 5               True           False                         False
#
#    cancellation_policy_moderate  cancellation_policy_other  \
# 0                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# 5                         False                      False
#
#    cancellation_policy_strict_14_with_grace_period
# 0                                             True
# 2                                             True
# 3                                             True
# 4                                             True
# 5                                             True
#
# [5 rows x 31 columns]

# %%
def avaliar_modelo(nome_modelo, y_teste, previsao):
    r2 = r2_score(y_teste, previsao)
    RSME = np.sqrt(mean_squared_error(y_teste, previsao))
    return f'Modelo {nome_modelo}:\nR²:{r2:.2%}\nRSME:{RSME:.2f}'

# %%
modelo_rf = RandomForestRegressor()
modelo_lr = LinearRegression()
modelo_et = ExtraTreesRegressor()

modelos = {'RandomForest': modelo_rf,
          'LinearRegression': modelo_lr,
          'ExtraTrees': modelo_et,
          }

y = base_airbnb_cod['price']
X = base_airbnb_cod.drop('price', axis=1)

display(y)
# Out:
# 0         307.0
# 2         159.0
# 3         253.0
# 4         350.0
# 5         221.0
#           ...
# 784115    335.0
# 784116    140.0
# 784117     55.0
# 784118    653.0
# 784119    132.0
# Name: price, Length: 489057, dtype: float32

# %% [markdown]
# separação de variaveis, treino e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)

for nome_modelo, modelo in modelos.items():
    #treinar
    modelo.fit(X_train, y_train)
    #testar
    previsao = modelo.predict(X_test)
    print(avaliar_modelo(nome_modelo, y_test, previsao))
# Out:
# Modelo RandomForest:
# R²:96.86%
# RSME:47.01
# Modelo LinearRegression:
# R²:31.94%
# RSME:218.89
# Modelo ExtraTrees:
# R²:97.05%
# RSME:45.57

# %%
print(modelo_et.feature_importances_)
print(X_train.columns)

importancia_feature = pd.DataFrame(modelo_et.feature_importances_,X_train.columns)
importancia_feature=importancia_feature.sort_values(by=0, ascending=False)
display(importancia_feature)

plt.figure(figsize=(15,5))
ax = sns.barplot(x=importancia_feature.index,y=importancia_feature[0])
ax.tick_params(axis='x',rotation=90)
# Out:
# [0.01407575 0.04167221 0.10575115 0.10356419 0.07652489 0.07183007
#  0.11571334 0.05266892 0.08871255 0.06724088 0.02250237 0.
#  0.09171573 0.01336833 0.00558631 0.00713953 0.00227807 0.00375777
#  0.00252663 0.05979446 0.0003216  0.00385614 0.00183614 0.0022985
#  0.00221895 0.00121003 0.01859793 0.01059027 0.00026986 0.01237741]
# Index(['host_is_superhost', 'host_listings_count', 'latitude', 'longitude',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'extra_people',
#        'minimum_nights', 'instant_bookable', 'is_business_travel_ready',
#        'n_amenities', 'property_type_Apartment', 'property_type_Condominium',
#        'property_type_House', 'property_type_Loft', 'property_type_Outros',
#        'property_type_Serviced apartment', 'room_type_Entire home/apt',
#        'room_type_Hotel room', 'room_type_Private room',
#        'room_type_Shared room', 'bed_type_Pull-out Sofa', 'bed_type_Real Bed',
#        'bed_type_other', 'cancellation_policy_flexible',
#        'cancellation_policy_moderate', 'cancellation_policy_other',
#        'cancellation_policy_strict_14_with_grace_period'],
#       dtype='object')
#                                                         0
# bedrooms                                         0.115713
# latitude                                         0.105751
# longitude                                        0.103564
# n_amenities                                      0.091716
# extra_people                                     0.088713
# accommodates                                     0.076525
# bathrooms                                        0.071830
# minimum_nights                                   0.067241
# room_type_Entire home/apt                        0.059794
# beds                                             0.052669
# host_listings_count                              0.041672
# instant_bookable                                 0.022502
# cancellation_policy_flexible                     0.018598
# host_is_superhost                                0.014076
# property_type_Apartment                          0.013368
# cancellation_policy_strict_14_with_grace_period  0.012377
# cancellation_policy_moderate                     0.010590
# property_type_House                              0.007140
# property_type_Condominium                        0.005586
# room_type_Private room                           0.003856
# property_type_Outros                             0.003758
# property_type_Serviced apartment                 0.002527
# bed_type_Pull-out Sofa                           0.002299
# property_type_Loft                               0.002278
# bed_type_Real Bed                                0.002219
# room_type_Shared room                            0.001836
# bed_type_other                                   0.001210
# room_type_Hotel room                             0.000322
# cancellation_policy_other                        0.000270
# is_business_travel_ready                         0.000000

# %% [markdown]
# ##ajustes finais

# %%
#print(base_airbnb_cod.isnull().sum())

# %%
base_airbnb_cod = base_airbnb_cod.drop('is_business_travel_ready',axis=1)
base_airbnb_cod = base_airbnb_cod.drop('cancellation_policy_other',axis=1)
base_airbnb_cod = base_airbnb_cod.drop('bed_type_other',axis=1)
base_airbnb_cod = base_airbnb_cod.drop('bed_type_Real Bed',axis=1)
base_airbnb_cod = base_airbnb_cod.drop('bed_type_Pull-out Sofa',axis=1)

y=base_airbnb_cod['price']
X=base_airbnb_cod.drop(['price'],axis=1)

X_train, X_test, y_train, y_test = train_test_split(X,y ,random_state=10)

modelo_et.fit(X_train,y_train)
previsao=modelo_et.predict(X_test)
print(avaliar_modelo('ExtraTrees',y_test, previsao))
# Out:
# Modelo ExtraTrees:
# R²:97.04%
# RSME:45.64

# %%
print(base_airbnb_cod.columns)
# Out:
# Index(['host_is_superhost', 'host_listings_count', 'latitude', 'longitude',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'extra_people', 'minimum_nights', 'instant_bookable', 'n_amenities',
#        'property_type_Apartment', 'property_type_Condominium',
#        'property_type_House', 'property_type_Loft', 'property_type_Outros',
#        'property_type_Serviced apartment', 'room_type_Entire home/apt',
#        'room_type_Hotel room', 'room_type_Private room',
#        'room_type_Shared room', 'cancellation_policy_flexible',
#        'cancellation_policy_moderate',
#        'cancellation_policy_strict_14_with_grace_period'],
#       dtype='object')

# %% [markdown]
# Deploy do projeto
#
# 1 criar arquivo do modulo (joblib)
#
# 2 escolher a forma de deploy
#     arquivo executavel + thinter
#     deploy em microsite
#     deploy apenas para uso direto (Streamlit)
# 3 outro arquivo python(juputer ou PyCharm)
# 4 importar streamlit criar codigo
# 5 atribuir ao botao o carregamento de modulo
# 6deploy

# %%
X['price'] = y
X.to_csv('dados.csv')

# %%
import joblib
joblib.dump(modelo_et,'modelo.joblib')
# Out:
# ['modelo.joblib']
