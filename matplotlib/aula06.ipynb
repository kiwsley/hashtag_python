# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#from matplotlib import colormaps

# %%
# convertendo os dados para listas
ano = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
receita = [42.9, 65.2, 108.2, 156.5, 170.9, 182.8, 233.7, 215.6, 229.2, 265.6, 260.2, 274.5, 365.8, 394.3]

# %%
#grafico de linhas
from cycler import cycler
#alterando a paleta de cores
cores = plt.get_cmap('Accent').colors
ciclo_cores = cycler('color',cores)
plt.rc('axes',prop_cycle=ciclo_cores)

plt.plot(ano, receita,marker='o')

#plt.plot(ano, [42.9, 65.2, 108.2, 16.5, 100.9, 180.8, 231.7, 212.6, 274.2, 265.6, 20.2, 24.5, 355.8, 394.3])


plt.title("Evolução da Receita da Apple")
plt.xlabel("Anos")
plt.ylabel("Receita( Bilhões de Dólares)")


plt.show()
