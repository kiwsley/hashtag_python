# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'SQLite3 ODBC Driver', 'SQLite ODBC Driver', 'SQLite ODBC (UTF-8) Driver']

# %%
dados_conexao = ("Driver={SQLite ODBC Driver};" 
                 "Server=localhost;" 
                 "Database=chinook.db")

conexao = pyodbc.connect(dados_conexao)
cursor = conexao.cursor()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[9], line 5
#       1 dados_conexao = ("Driver={SQLite ODBC Driver};"
#       2                  "Server=localhost;"
#       3                  "Database=chinook.db")
# ----> 5 conexao = pyodbc.connect(dados_conexao)
#       6 cursor = conexao.cursor()
#
# Error: ('HY000', '[HY000] out of memory (-1) (SQLDriverConnect)')

# %%
cursor.close()
conexao.close() #Finalizando a conexao
